# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from ISLP import load_data
auto = load_data("Auto")

# %%
auto = auto.dropna()
auto
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0         130    3504
# buick skylark 320          15.0          8         350.0         165    3693
# plymouth satellite         18.0          8         318.0         150    3436
# amc rebel sst              16.0          8         304.0         150    3433
# ford torino                17.0          8         302.0         140    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0          86    2790
# vw pickup                  44.0          4          97.0          52    2130
# dodge rampage              32.0          4         135.0          84    2295
# ford ranger                28.0          4         120.0          79    2625
# chevy s-10                 31.0          4         119.0          82    2720
#
# ...

# %% [markdown]
# quantitative predictors
#
# mpg
#
# displacement
#
# horsepower
#
# weight
#
# acceleration
#
# year
#
# cylinders
#
# Qualitative predictors:
#
# origin
#
# name

# %%
auto.describe()[['mpg', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'cylinders']].loc[['min', 'max']]
# Out:
#       mpg  displacement  horsepower  weight  acceleration  year  cylinders
# min   9.0          68.0        46.0  1613.0           8.0  70.0        3.0
# max  46.6         455.0       230.0  5140.0          24.8  82.0        8.0

# %%
auto[['mpg', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'cylinders']].agg(['mean', 'std'])
# Out:
#             mpg  displacement  horsepower       weight  acceleration  \
# mean  23.445918    194.411990  104.469388  2977.584184     15.541327
# std    7.805007    104.644004   38.491160   849.402560      2.758864
#
#            year  cylinders
# mean  75.979592   5.471939
# std    3.683737   1.705783

# %%
auto_reduced = auto.drop(auto.index[9:85])
auto_reduced.describe().loc[['min', 'max', 'mean', 'std']]
# Out:
#             mpg  cylinders  displacement  horsepower       weight  \
# min   11.000000   3.000000     68.000000   46.000000  1755.000000
# max   46.600000   8.000000    455.000000  230.000000  4952.000000
# mean  25.041637   5.274021    179.373665   98.715302  2881.505338
# std    7.912874   1.632155     95.512897   33.822711   792.548494
#
#       acceleration       year    origin
# min       9.500000  70.000000  1.000000
# max      24.600000  82.000000  3.000000
# mean     15.738790  77.508897  1.633452
# std       2.570191   2.989403  0.830760

# %%
sns.pairplot(auto[['mpg', 'displacement', 'horsepower', 'weight', 'acceleration']])
plt.show()

# %% [markdown]
# Yes. Based on the scatterplots and correlation analysis
# Weight and horsepower show strong negative correlations with mpg. Heavier and more powerful cars tend to have lower fuel efficiency
